# %% [markdown]
# # Video processing

# %% [markdown]
# ## Recording a video

# %% [markdown]
# ## Converting a video to frames

# %%
import cv2
import matplotlib.pyplot as plt

vidcap = cv2.VideoCapture('video-test-milica.mp4')
success,image = vidcap.read()
images=[]

while success:   
    success, image = vidcap.read()
    images.append(image)

plt.imshow(images[50])

# %%
len(images)
# Out:
# 171

# %% [markdown]
# ## Extracting the face

# %%
from skimage import color
images_just_faces=[]
for image in images:
    try:
        image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        #image = color.rgb2gray(images[10])
        plt.imshow(image)

        face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')
 
        faces = face_cascade.detectMultiScale(
        image,
        scaleFactor=1.3,
        minNeighbors=3,
        minSize=(30, 30)
                )
        for (x, y, w, h) in faces:
            cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)
            just_face = image[y:y + h, x:x + w]
            images_just_faces.append(just_face)
    except:
        pass
plt.imshow(images_just_faces[10])

# %%
len(images_just_faces)
# Out:
# 154

# %%
len(images)
# Out:
# 171
